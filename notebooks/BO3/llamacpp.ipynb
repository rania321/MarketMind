# %%
# !nvidia-smi
# Out:
# Sat Mar  8 15:24:34 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install --upgrade llama-cpp-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 MB 10.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.1 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.8-cp311-cp311-linux_x86_64.whl size=5959957 sha256=02f1f09b92960757ad4b27bedc13870942ac2c1b18f15cc2e50895b9ed16c47e
#   Stored in directory: /root/.cache/pip/wheels/c0/03/66/eb3810eafd55d921b2be32896d1f44313996982360663aa80b
# Successfully built llama-cpp-python
# ...

# %%
from huggingface_hub import hf_hub_download
from llama_cpp import Llama

# Replace with your GGUF model's Hugging Face repository path
model_name = "Ahmed3310/lora_model_marketmind_v1_gguf_v1"

# Download the GGUF model to local storage
model_path = hf_hub_download(repo_id=model_name, filename="unsloth.Q4_K_M.gguf")

# Load the GGUF model from the downloaded path
# Out:
# unsloth.Q4_K_M.gguf:   0%|          | 0.00/4.92G [00:00<?, ?B/s]

# %%
llm = Llama(
    model_path=model_path,
    n_ctx=2048,  # Adjust context length if needed
    n_gpu_layers=40  # Use GPU layers if available
)
# Out:
# llama_model_loader: loaded meta data with 31 key-value pairs and 292 tensors from /root/.cache/huggingface/hub/models--Ahmed3310--lora_model_marketmind_v1_gguf_v1/snapshots/7e3eb07723a87380c0f6897be41e1b479d4bdaad/unsloth.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Meta Llama 3.1 8b Instruct Bnb 4bit
# llama_model_loader: - kv   3:                       general.organization str              = Unsloth
# llama_model_loader: - kv   4:                           general.finetune str              = instruct-bnb-4bit
# ...

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{instruction}

### Input:
{input}

### Response:
{output}"""
instruction = "Generate an SDXL design prompt for the following product."
input_text = "Lunar Glow Night Cream,A luxurious night cream infused with moonflower extract and hyaluronic acid, designed to rejuvenate skin overnight."
output = ""  # Leave blank for generation

prompt = alpaca_prompt.format(
    instruction=instruction,
    input=input_text,
    output=output
)

# Generate the response
response = llm(prompt, max_tokens=256)  # Stop at "###" to avoid continuing beyond the response

# Print the generated text
print(response['choices'][0]['text'])
# Out:
# llama_perf_context_print:        load time =   19369.51 ms
# llama_perf_context_print: prompt eval time =   19369.29 ms /    76 tokens (  254.86 ms per token,     3.92 tokens per second)
# llama_perf_context_print:        eval time =   24077.68 ms /    67 runs   (  359.37 ms per token,     2.78 tokens per second)
# llama_perf_context_print:       total time =   43517.95 ms /   143 tokens
# Create a serene promotional image for Lunar Glow Night Cream. The cream is in a glass jar with a silver lid, placed centrally on a moonlit night table. Use a soft blue and white color palette with glowing moonbeams. Typography: Elegant serif font in silver. Style: Dreamy, soft focus, 8K resolution.
